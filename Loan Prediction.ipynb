# %% [markdown]
# ## EDA PART :-1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\hp\\Downloads\\train_ctrUa4K.csv"
loan_df=pd.read_csv(file_path)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
shape=loan_df.shape    # it gives number of rows and column of the data
shape
# Out:
# (614, 13)

# %%
size=loan_df.size      # it gives multiple of rows and column
size
# Out:
# 7982

# %%
dtypes=loan_df.dtypes    # it gives information about which column are object and which are intiger
dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
index=loan_df.index   # it gives starting index , last index and step 
index
# Out:
# RangeIndex(start=0, stop=614, step=1)

# %%
values=loan_df.values  # it gives total values of all the rows and columns
values
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 'Y'],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 'N'],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 'Y'],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 'N']],
#       dtype=object)

# %%
loan_df.replace({"3+":"4"})
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ##### Seperate categorical and numerical

# %% [markdown]
# $Method:-1$

# %%
cat=[]
num=[]
data=loan_df.dtypes
dict1=dict(data)
for i in dict1:
    if dict1[i]=='O':
        cat.append(i)
    else:
        num.append(i)
print('cat:',cat)
print('num:',num)
# Out:
# cat: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# num: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %% [markdown]
# $Method:-2$

# %%
cat=[column for column,dtype in data.items() if dtype=='O']
num=[column for column,dtype in data.items() if dtype!='O']
print('cat:',cat)
print('num:',num)
# Out:
# cat: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# num: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %% [markdown]
# $Head$

# %%
loan_df.head()  # it gives starting 5 rows
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_df.head(10)  # it gives starting 10 rows
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %% [markdown]
# $Tail$

# %%
loan_df.tail()   # it gives last 5 rows values
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.tail(10)  # it gives last 10 rows
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %% [markdown]
# $Take$

# %%
loan_df.take([1,4,5,9])  # use for select a particular rows
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 1  LP001003   Male     Yes          1  Graduate            No
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
# 9  LP001020   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %%
loan_df.take([200,450,340,300]).take([1,4,5,7],axis=1)   # use for select a particular rows and columns
# Out:
#     Gender     Education Self_Employed  CoapplicantIncome
# 200   Male  Not Graduate            No             2500.0
# 450   Male  Not Graduate            No             1255.0
# 340   Male  Not Graduate            No             1587.0
# 300   Male  Not Graduate            No             2934.0

# %% [markdown]
# $loc-iloc$

# %%
loan_df.iloc[10:20,2:7]   #  a particular range of rows and columns
# Out:
#    Married Dependents     Education Self_Employed  ApplicantIncome
# 10     Yes          2      Graduate            No             3200
# 11     Yes          2      Graduate           NaN             2500
# 12     Yes          2      Graduate            No             3073
# 13      No          0      Graduate            No             1853
# 14     Yes          2      Graduate            No             1299
# 15      No          0      Graduate            No             4950
# 16      No          1  Not Graduate            No             3596
# 17      No          0      Graduate            No             3510
# 18     Yes          0  Not Graduate            No             4887
# 19     Yes          0      Graduate           NaN             2600

# %%
rows=[100,200,300]  
cols=['Married','Education']
loan_df.loc[rows,cols]
# Out:
#     Married     Education
# 100     Yes  Not Graduate
# 200     Yes  Not Graduate
# 300     Yes  Not Graduate

# %%
loan_df.loc[20:30,['Self_Employed','ApplicantIncome','Married',"Education"]]   # using a particluar range of rows and column
# Out:
#    Self_Employed  ApplicantIncome Married     Education
# 20            No             7660     Yes  Not Graduate
# 21            No             5955     Yes      Graduate
# 22            No             2600     Yes  Not Graduate
# 23            No             3365     Yes  Not Graduate
# 24           NaN             3717     Yes      Graduate
# 25           Yes             9560     Yes      Graduate
# 26            No             2799     Yes      Graduate
# 27            No             4226     Yes  Not Graduate
# 28            No             1442      No  Not Graduate
# 29           NaN             3750      No      Graduate
# 30           NaN             4166     Yes      Graduate

# %%
loan_df.columns   # gives all column name
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.select_dtypes(exclude='object')  # it gives values of all column except object
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# ...

# %%
loan_df.select_dtypes(exclude='object').columns   # It gives all columns except object types
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
loan_df.select_dtypes(include='object').columns   # it gives all categorical column
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# $Isnull$

# %%
loan_df.isnull()   # it return missing values as True Otherwise false
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_df.isnull().sum()   # it gives total missing values in each columns
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# $Len$

# %%
len(loan_df)   # it gives total rows
# Out:
# 614

# %% [markdown]
#  **Missing Values Analysis**
#
# $Method:-1$
#
# - Replacing with random values

# %%
loan_df.isnull()  # all the missing values place Return True
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_df.isnull().sum()   # it gives total  number of missing values in every column
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df=loan_df.fillna('40')    # 40 willreplace in all the missing values
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5849                0.0         40            360.0
# ...

# %%
df.isnull().sum()    # re checking is there any missing values or not
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# $Method:-2$
#
# **Replacing with upper values and lower values in columns**

# %%
df=loan_df.fillna(method='bfill')  # method use to fill the empty value by using the previous values
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum() # re check after the method use
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df=loan_df.fillna(method='ffill')  # this method use to fill missing values by using upper values of thsa same column
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()  # re check again after using the method any missing values are available or not
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           1
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_df.replace({"3+":"4"})
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
for column,dtype in loan_df.dtypes.items():
    if dtype=='object':
        loan_df[column].fillna(loan_df[column].mode()[0],inplace=True)
    else:
        loan_df[column].fillna(loan_df[column].median(),inplace=True)

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['Dependents'].replace({"3+":"4"},inplace=True)

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ## EDA PART:-2
#
# **Categorical Data Analysis**

# %% [markdown]
# **How to read a column**

# %%
loan_df.columns   # it gives all the column names
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
type(loan_df.columns)   # It gives types of columns
# Out:
# pandas.core.indexes.base.Index

# %%
loan_df['Property_Area']   # used to read a particular column
# Out:
# 0          Urban
# 1          Rural
# 2          Urban
# 3          Urban
# 4          Urban
#          ...
# 609        Rural
# 610        Rural
# 611        Urban
# 612        Urban
# 613    Semiurban
# Name: Property_Area, Length: 614, dtype: object

# %%
type(loan_df['Property_Area'] )  # it gives type of column that is the column is in series
# Out:
# pandas.core.series.Series

# %%
loan_df[['Property_Area']]    # used to read particular column
# Out:
#     Property_Area
# 0           Urban
# 1           Rural
# 2           Urban
# 3           Urban
# 4           Urban
# ..            ...
# 609         Rural
# 610         Rural
# 611         Urban
# 612         Urban
# 613     Semiurban
#
# [614 rows x 1 columns]

# %%
type(loan_df[['Property_Area']]) # it gives type of column that is in dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Read Two or more  column at a time**

# %%
cols=['Loan_ID', 'Gender', 'Married', 'Dependents']       # read more than two column at a time
loan_df[cols]
# Out:
#       Loan_ID  Gender Married Dependents
# 0    LP001002    Male      No          0
# 1    LP001003    Male     Yes          1
# 2    LP001005    Male     Yes          0
# 3    LP001006    Male     Yes          0
# 4    LP001008    Male      No          0
# ..        ...     ...     ...        ...
# 609  LP002978  Female      No          0
# 610  LP002979    Male     Yes          4
# 611  LP002983    Male     Yes          1
# 612  LP002984    Male     Yes          2
# 613  LP002990  Female      No          0
#
# [614 rows x 4 columns]

# %%
type(loan_df[cols])     # type of the column is dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Unique**

# %%
loan_df['Property_Area'].unique()    # it gives the unique values of a particular column
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
loan_df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %% [markdown]
# **Nunique**

# %%
loan_df['Property_Area'].nunique()   # it gives total number of values of a particular colmun
                                     # here three values are repeated of the time thats why it return 3
# Out:
# 3

# %%
loan_df['Education'].nunique()      # it gives total number of values of a particular colmun
                                 # here two values are repeated of the seveal time thats why it return 2
# Out:
# 2

# %% [markdown]
# **Value Counts**

# %%
loan_df['Property_Area'].value_counts()   # it gives total values of all the outputs of a particular column
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
len(loan_df[loan_df['Property_Area']=='Semiurban'])
# Out:
# 233

# %%
count=0
for i in loan_df['Property_Area']:
    if i=='Semiurban':
        count=count+1
print(count)
# Out:
# 233

# %% [markdown]
# **Create a frequency table by our own skill**

# %%
x=loan_df['Property_Area'].unique()
for i in x:
    count=len(loan_df[loan_df['Property_Area']==i])
    print(i,':',count)
# Out:
# Urban : 202
# Rural : 179
# Semiurban : 233

# %%
loan_df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
cat
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
x=loan_df['Education'].unique()
for i in x:
    count=len(loan_df[loan_df['Education']==i])
    print(i,':',count)
# Out:
# Graduate : 480
# Not Graduate : 134

# %%
x=loan_df['Gender'].unique()
for i in x:
    count=len(loan_df[loan_df['Gender']==i])
    print(i,':',count)
# Out:
# Male : 502
# Female : 112

# %%
loan_df['Gender'].value_counts()
Property=loan_df['Gender'].value_counts().keys()
count=loan_df['Gender'].value_counts().values
Data=pd.DataFrame(zip(Property,count),columns=['Gender','Count'],index=['Male','female'])
Data
# Out:
#         Gender  Count
# Male         1    502
# female       0    112

# %%
loan_df['Education'].value_counts()
Property=loan_df['Education'].value_counts().keys()
count=loan_df['Education'].value_counts().values
Data=pd.DataFrame(zip(Property,count),columns=['Education','Count'],index=['graduate' ,'non graduate'])
Data
# Out:
#               Education  Count
# graduate              1    480
# non graduate          0    134

# %% [markdown]
# #### Bar Chart

# %%
loan_df['Property_Area'].value_counts()
Property=loan_df['Property_Area'].value_counts().keys()
count=loan_df['Property_Area'].value_counts().values
Data=pd.DataFrame(zip(Property,count),columns=['Property','Count'])
Data
# Out:
#     Property  Count
# 0  Semiurban    233
# 1      Urban    202
# 2      Rural    179

# %%
plt.figure(figsize=(5,3))
plt.bar('Property','Count',data=Data)
plt.title('Propert Chart')
plt.xlabel('Property')
plt.ylabel('Count')
plt.show()

# %%
for column in cat[1:]:
    
    loan_df[column].value_counts()
    Property=loan_df[column].value_counts().keys()
    count=loan_df[column].value_counts().values
    Data=pd.DataFrame(zip(Property,count),columns=[column,'Count'])
    Data
    
    plt.figure(figsize=(10,10))
    
    plt.subplot(2,2,1)
    plt.title(f'{column} bar chart')
    plt.bar(column,'Count',data=Data)
    
    plt.xlabel(column)
    plt.ylabel('Count')
    
   
    plt.subplot(2,2,2)
    plt.title(f'{column} pie chart')
    plt.pie(x=count,labels=Property,autopct='%0.2f%%')
    
    plt.show()

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(cat[1:]):
    plt.subplot(4,2,i+1)

    ax=sns.countplot(data=loan_df,x=column)
    ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
plt.figure(figsize=(15,15))
for i,column in enumerate(cat[1:]):
    plt.subplot(4,2,i+1)
    loan_df[column].value_counts()
    Property=loan_df[column].value_counts(normalize=True).keys()
    count=loan_df[column].value_counts(normalize=True).values
    Data=pd.DataFrame(zip(Property,count),columns=[column,'Count'])
    n=loan_df[column].nunique()
    l=[0.1 for i in range(n)]
    plt.title(column)
    plt.pie(x=count,labels=Property,autopct='%0.2f%%',shadow=True,radius=1,startangle=90,explode=l)
plt.show()

# %% [markdown]
# ## EDA PART:-3
#
# **Numerical Data Analysis**

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
cat=[]
num=[]
data=loan_df.dtypes
dict1=dict(data)
for i in dict1:
    if dict1[i]=='O':
        cat.append(i)
    else:
        num.append(i)
print('cat:',cat)
print('num:',num)
# Out:
# cat: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# num: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %% [markdown]
# **Stastical Measurement**
#
# - Mean
#
# - Median
#
# - Count
#
# - max
#
# - min
#
# - std
#
# - 25
#
# - 50
#
# - 75

# %%
count=round(loan_df['CoapplicantIncome'].count(),2)
Max=round(loan_df['CoapplicantIncome'].max(),2)
Min=round(loan_df['CoapplicantIncome'].min(),2)
mean=round(loan_df['CoapplicantIncome'].mean(),2)
median=round(loan_df['CoapplicantIncome'].median(),2)
std=round(loan_df['CoapplicantIncome'].std(),2)
print(count,Max,Min,mean,median,std)
# Out:
# 614 41667.0 0.0 1621.25 1188.5 2926.25

# %%
# store all the values in a dictionary

dict1={}
count=round(loan_df['CoapplicantIncome'].count(),2)
Max=round(loan_df['CoapplicantIncome'].max(),2)
Min=round(loan_df['CoapplicantIncome'].min(),2)
mean=round(loan_df['CoapplicantIncome'].mean(),2)
median=round(loan_df['CoapplicantIncome'].median(),2)
std=round(loan_df['CoapplicantIncome'].std(),2)
list1=[count,Max,Min,mean,median,std]
dict1['CoapplicantIncome']=list1
dict1
pd.DataFrame(dict1,index=['count','Max','Min','mean','median','std'])
# Out:
#         CoapplicantIncome
# count              614.00
# Max              41667.00
# Min                  0.00
# mean              1621.25
# median            1188.50
# std               2926.25

# %%
# store the value using list
count=round(loan_df['CoapplicantIncome'].count(),2)
Max=round(loan_df['CoapplicantIncome'].max(),2)
Min=round(loan_df['CoapplicantIncome'].min(),2)
mean=round(loan_df['CoapplicantIncome'].mean(),2)
median=round(loan_df['CoapplicantIncome'].median(),2)
std=round(loan_df['CoapplicantIncome'].std(),2)
list1=[count,Max,Min,mean,median,std]
pd.DataFrame(list1,columns=['CoapplicantIncome'],index=['count','Max','Min','mean','median','std'])
# Out:
#         CoapplicantIncome
# count              614.00
# Max              41667.00
# Min                  0.00
# mean              1621.25
# median            1188.50
# std               2926.25

# %%
dtypes=dict(loan_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)
dict1={}
for i in num:
    count=round(loan_df['CoapplicantIncome'].count(),2)
    Max=round(loan_df['CoapplicantIncome'].max(),2)
    Min=round(loan_df['CoapplicantIncome'].min(),2)
    mean=round(loan_df['CoapplicantIncome'].mean(),2)
    median=round(loan_df['CoapplicantIncome'].median(),2)
    std=round(loan_df['CoapplicantIncome'].std(),2)
    list1=[count,Max,Min,mean,median,std]
    dict1[i]=list1
df=pd.DataFrame(dict1,index=['count','Max','Min','mean','median','std'])
df
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count            614.00             614.00      614.00            614.00
# Max            41667.00           41667.00    41667.00          41667.00
# Min                0.00               0.00        0.00              0.00
# mean            1621.25            1621.25     1621.25           1621.25
# median          1188.50            1188.50     1188.50           1188.50
# std             2926.25            2926.25     2926.25           2926.25
#
#         Credit_History
# count           614.00
# Max           41667.00
# Min               0.00
# mean           1621.25
# median         1188.50
# std            2926.25

# %% [markdown]
# **Percentile-Quantile**

# %%
# percentile
p1=round(np.percentile(loan_df['CoapplicantIncome'],25),2)
p2=round(np.percentile(loan_df['CoapplicantIncome'],50),2)
p3=round(np.percentile(loan_df['CoapplicantIncome'],75),2)

print(p1,p2,p3)
# Out:
# 0.0 1188.5 2297.25

# %%
q1=round(np.quantile(loan_df['CoapplicantIncome'],0.25),2)
q2=round(np.quantile(loan_df['CoapplicantIncome'],0.50),2)
q3=round(np.quantile(loan_df['CoapplicantIncome'],0.75),2)

print(q1,q2,q3)
# Out:
# 0.0 1188.5 2297.25

# %%
dtypes=dict(loan_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)
dict1={}
for i in num:
    count=round(loan_df[i].count(),2)
    Max=round(loan_df[i].max(),2)
    Min=round(loan_df[i].min(),2)
    mean=round(loan_df[i].mean(),2)
    median=round(loan_df[i].median(),2)
    std=round(loan_df[i].std(),2)
    
    q1=round(np.quantile(loan_df[i],0.25),2)
    q2=round(np.quantile(loan_df[i],0.50),2)
    q3=round(np.quantile(loan_df[i],0.75),2)
    list1=[count,Max,Min,mean,median,std,q1,q2,q3]
    dict1[i]=list1
df=pd.DataFrame(dict1,index=['count','max','Min','mean','median','std','q1','q2','q3'])
df
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count            614.00             614.00      614.00            614.00
# max            81000.00           41667.00      700.00            480.00
# Min              150.00               0.00        9.00             12.00
# mean            5403.46            1621.25      145.75            342.41
# median          3812.50            1188.50      128.00            360.00
# std             6109.04            2926.25       84.11             64.43
# q1              2877.50               0.00      100.25            360.00
# q2              3812.50            1188.50      128.00            360.00
# q3              5795.00            2297.25      164.75            360.00
#
#         Credit_History
# count           614.00
# max               1.00
# Min               0.00
# mean              0.86
# median            1.00
# ...

# %% [markdown]
# **Describe Function**

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(10,15))
for i,column in enumerate(num):
    plt.subplot(4,2,i+1)
    plt.title(column)
    plt.hist(loan_df[column],bins=40)
plt.show()

# %% [markdown]
# ## Empirical rule

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
applicantIncome_mean=round(loan_df['ApplicantIncome'].mean(),2)
applicantIncome_std=round(loan_df['ApplicantIncome'].std(),2)
print(applicantIncome_mean,applicantIncome_std)
# Out:
# 5403.46 6109.04

# %%
val_minus_1=round(applicantIncome_mean-1*applicantIncome_std,2)
val_plus_1=round(applicantIncome_mean+1*applicantIncome_std,2)
print(val_minus_1,val_plus_1)
# Out:
# -705.58 11512.5

# %%
val_minus_2=round(applicantIncome_mean-2*applicantIncome_std,2)
val_plus_2=round(applicantIncome_mean+2*applicantIncome_std,2)
print(val_minus_2,val_plus_2)
# Out:
# -6814.62 17621.54

# %%
val_minus_3=round(applicantIncome_mean-3*applicantIncome_std,2)
val_plus_3=round(applicantIncome_mean+3*applicantIncome_std,2)
print(val_minus_3,val_plus_3)
# Out:
# -12923.66 23730.58

# %%
con1=loan_df['ApplicantIncome']>val_minus_1
con2=loan_df['ApplicantIncome']<val_plus_1
len(loan_df[con1&con2])
len(loan_df[con1&con2])/len(loan_df)
# Out:
# 0.9348534201954397

# %%
con1=loan_df['ApplicantIncome']>val_minus_2
con2=loan_df['ApplicantIncome']<val_plus_2
len(loan_df[con1&con2])
len(loan_df[con1&con2])/len(loan_df)
# Out:
# 0.9739413680781759

# %%
con1=loan_df['ApplicantIncome']>val_minus_3
con2=loan_df['ApplicantIncome']<val_plus_3
len(loan_df[con1&con2])
len(loan_df[con1&con2])/len(loan_df)
# Out:
# 0.9869706840390879

# %%
def empirical_analysis(col):
    mu = loan_df[col].mean()
    sigma = loan_df[col].std()
    minus1 = mu - sigma ; plus1 = mu + sigma
    minus2 = mu - (2*sigma) ; plus2 = mu + (2*sigma)
    minus3 = mu - (3*sigma) ; plus3 = mu + (3*sigma)
    x1 = loan_df[(loan_df[col] > minus1) & (loan_df[col] < plus1)]
    x2 = loan_df[(loan_df[col] > minus2) & (loan_df[col] < plus2)]
    x3 = loan_df[(loan_df[col] > minus3) & (loan_df[col] < plus3)]
    return(x1,x2,x3)

# %%
 for i in num:
    x=empirical_analysis(i)
    print(x)
# Out:
# (      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## EDA :- 4

# %%
num
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
plt.figure(figsize=(15,20))
for i,column in enumerate(num):
    plt.subplot(4,2,i+1)
    plt.title(column)
    plt.boxplot(loan_df[column])
plt.show()

# %%
def median_imputed(col):
    q1=np.quantile(loan_df[col],0.25)
    q2=np.quantile(loan_df[col],0.50)
    q3=np.quantile(loan_df[col],0.75)

    Iqr=q3-q1
    ub=q3+(1.5*Iqr)
    lb=q1-(1.5*Iqr)
    con1=loan_df[col]>ub
    con2=loan_df[col]<lb
    outliers_df=loan_df[con1|con2]
    new_values=[]
    median=round(loan_df[col].median(),2)
    for i in loan_df[col].values:
        if i>ub or i<lb:
            new_values.append(median)
        else:
            new_values.append(i)

    loan_df[f'{col}_imputed'] = new_values

# %%
#loan_df['ApplicantIncome'].values

# %%
for i in num:
    median_imputed(i)

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#file_path="C:\\Users\\hp\\Downloads\\train_ctrUa4K.csv"
#loan_df=pd.read_csv(file_path)

q1=np.quantile(loan_df['LoanAmount'],0.25)
q2=np.quantile(loan_df['LoanAmount'],0.50)
q3=np.quantile(loan_df['LoanAmount'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=loan_df['LoanAmount']>ub
con2=loan_df['LoanAmount']<lb
outliers_df=loan_df[con1|con2]
outliers_df
#con1|con
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 9    LP001020    Male     Yes          1      Graduate            No
# 21   LP001046    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No          4      Graduate            No
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 67   LP001233    Male     Yes          1      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 126  LP001448    Male     Yes          4      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 135  LP001488    Male     Yes          4      Graduate            No
# 155  LP001536    Male     Yes          4      Graduate            No
# 161  LP001562    Male     Yes          0      Graduate            No
# 171  LP001585    Male     Yes          4      Graduate            No
# ...

# %%
len(outliers_df),len(loan_df),len(outliers_df)*100/len(loan_df)
# Out:
# (41, 614, 6.677524429967427)

# %%
q1=np.quantile(loan_df['LoanAmount'],0.25)
q2=np.quantile(loan_df['LoanAmount'],0.50)
q3=np.quantile(loan_df['LoanAmount'],0.75)

Iqr=q3-q1
ub=q3+(1.5*Iqr)
lb=q1-(1.5*Iqr)
con1=loan_df['LoanAmount']<ub
con2=loan_df['LoanAmount']>lb
non_outliers_df=loan_df[con1&con2]
#outliers_df
#con1|con

# %%
len(non_outliers_df),len(loan_df),len(non_outliers_df)*100/len(loan_df)
# Out:
# (573, 614, 93.32247557003258)

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.title('non_outliers data')
plt.hist(non_outliers_df['LoanAmount'])

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['LoanAmount'])

plt.subplot(2,2,3)
plt.title('non_outliers data')
plt.boxplot(non_outliers_df['LoanAmount'])

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['LoanAmount'])
plt.show()

# %%
new_values=[]
median=round(loan_df['LoanAmount'].median(),2) ##  put all as i and aply for loop on the top numerical column
for i in loan_df['LoanAmount'].values:
    if i>ub or i<lb:
        new_values.append(median)
    else:
        new_values.append(i)
new_values

loan_df['LoanAmount_imputed']=new_values    

loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('LoanAmount_imputed')
plt.hist(loan_df['LoanAmount_imputed'],bins=40)

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['LoanAmount'],bins=40)

plt.subplot(2,2,3)
plt.title('LoanAmount_imputed')
plt.boxplot(loan_df['LoanAmount_imputed'],vert=False)

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['LoanAmount'],vert=False)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('ApplicantIncome_imputed')
plt.hist(loan_df['ApplicantIncome_imputed'],bins=40)

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['ApplicantIncome'],bins=40)

plt.subplot(2,2,3)
plt.title('ApplicantIncome_imputed')
plt.boxplot(loan_df['ApplicantIncome_imputed'],vert=False)

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['ApplicantIncome'],vert=False)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('CoapplicantIncome_imputed')
plt.hist(loan_df['CoapplicantIncome_imputed'],bins=40)

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['CoapplicantIncome'],bins=40)

plt.subplot(2,2,3)
plt.title('CoapplicantIncome_imputed')
plt.boxplot(loan_df['CoapplicantIncome_imputed'],vert=False)

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['CoapplicantIncome'],vert=False)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('Loan_Amount_Term_imputed')
plt.hist(loan_df['Loan_Amount_Term_imputed'],bins=40)

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['Loan_Amount_Term'],bins=40)

plt.subplot(2,2,3)
plt.title('Loan_Amount_Term_imputed')
plt.boxplot(loan_df['Loan_Amount_Term_imputed'],vert=False)

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['Loan_Amount_Term'],vert=False)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title('Credit_History_imputed')
plt.hist(loan_df['Credit_History_imputed'],bins=40)

plt.subplot(2,2,2)
plt.title('original data')
plt.hist(loan_df['Credit_History'],bins=40)

plt.subplot(2,2,3)
plt.title('Credit_History_imputed')
plt.boxplot(loan_df['Credit_History_imputed'],vert=False)

plt.subplot(2,2,4)
plt.title('original data')
plt.boxplot(loan_df['Credit_History'],vert=False)
plt.show()

# %%
loan_df.drop(columns=['ApplicantIncome',
                     'CoapplicantIncome',
                     'LoanAmount',
                     'Loan_Amount_Term',
                     'Credit_History'],axis=1,inplace=True)

# %%
cat=[]
num=[]
data=loan_df.dtypes
dict1=dict(data)
for i in dict1:
    if dict1[i]=='O':
        cat.append(i)
    else:
        num.append(i)
print('cat:',cat)
print('num:',num)
# Out:
# cat: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# num: ['ApplicantIncome_imputed', 'CoapplicantIncome_imputed', 'LoanAmount_imputed', 'Loan_Amount_Term_imputed', 'Credit_History_imputed']

# %%
for i in range (len(num)):
    q1=np.percentile(loan_df[num[i]],25)
    q2=np.percentile(loan_df[num[i]],50)
    q3=np.percentile(loan_df[num[i]],75)
    iqr=q3-q1
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    con1=loan_df[num[i]]>ub
    con2=loan_df[num[i]]<lb
    con=con1|con2
    median=loan_df[num[i]].median()
    loan_df[i]=np.where(con,median,loan_df[num[i]])
    plt.subplot(3,2,i+1)
    plt.boxplot(loan_df[num[i]])

# %%
import warnings
warnings.filterwarnings('ignore',category=UserWarning)

for i in range(len(num)):
    plt.figure(figsize=(8,8))
    plt.subplot(3,2,i+1)
    plt.boxplot(loan_df[num[i]])
    plt.title(num[i])
    plt.tight_layout()

# %%
for i in range(len(num)):
    #plt.figure(figsize=(10,5))
    plt.subplot(3,2,i+1)
    plt.boxplot(loan_df[num[i]])
    plt.title(num[i])
    plt.tight_layout()

# %%
for i in range(len(num)):
    q1=np.percentile(loan_df[num[i]],25)
    q2=np.percentile(loan_df[num[i]],50)
    q3=np.percentile(loan_df[num[i]],75)
    iqr=q3-q1
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    con1=loan_df[num[i]]>ub
    con2=loan_df[num[i]]<lb
    con=con1|con2
    median=loan_df[num[i]].median()
    loan_df[num[i]]=np.where(con,median,loan_df[num[i]])
    plt.subplot(3,2,i+1)
    plt.boxplot(loan_df[num[i]])
    plt.show()

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0           Urban           Y                  5849.00
# ...

# %% [markdown]
# ## EDA PART:-5

# %% [markdown]
# *Bi Variate And Multivariate*

# %%
cat[1:]
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
for i in cat[1:]:
    for j in cat[2:]:
        if i!=j:
            loan_df[[i,j]].value_counts().plot(kind='bar')
          
            
#             plt.subplot(12,3,l+1)
        plt.figure(figsize=(2,2))
        plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total number of plots (rows * columns)
total_plots = 9 * 4

# Create a figure and axes for the subplots
fig, axes = plt.subplots(9, 4, figsize=(15, 40))  # 9 rows, 4 columns - Adjust the figsize as needed

# Your existing code with minor modifications
plot_counter = 0  # Initialize a counter for subplot positions

for i in cat[1:]:
    for j in cat[2:]:
        if i != j and plot_counter < total_plots:  # Check if plot_counter exceeds total_plots
            ax = axes[plot_counter // 4, plot_counter % 4]  # Get the current subplot
            loan_df[[i, j]].value_counts().plot(kind='bar', ax=ax)
            ax.set_title(f'Columns: {i} vs {j}')
            plot_counter += 1  # Increment the plot counter

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
col1=loan_df['Gender']
col2=loan_df['Married']
col3=loan_df['Dependents']
col4=loan_df['Education']
col5=loan_df['Self_Employed']
col6=loan_df['Property_Area']
col7=loan_df['Loan_Status']
col=[col2,col4,col5]
result=pd.crosstab(col1,col)
#result
result.plot(kind='bar')
plt.show()

# %%
col1=loan_df['Gender']
col2=loan_df['Married']
col3=loan_df['Dependents']
col4=loan_df['Education']
col5=loan_df['Self_Employed']
col6=loan_df['Property_Area']
col7=loan_df['Loan_Status']
col=[col3,col7]
result=pd.crosstab(col1,col)
#result
result.plot(kind='bar')
plt.show()

# %%
col1=loan_df['Gender']
col2=loan_df['Married']
col3=loan_df['Dependents']
col4=loan_df['Education']
col5=loan_df['Self_Employed']
col6=loan_df['Property_Area']
col7=loan_df['Loan_Status']
col=[col1,col4]
result=pd.crosstab(col7,col)
#result
result.plot(kind='bar')
plt.show()

# %%
col1=loan_df['Gender']
col2=loan_df['Married']
col3=loan_df['Dependents']
col4=loan_df['Education']
col5=loan_df['Self_Employed']
col6=loan_df['Property_Area']
col7=loan_df['Loan_Status']
col=[col5,col3]
result=pd.crosstab(col7,col)
#result
result.plot(kind='bar')
plt.show()

# %%
col1=loan_df['Gender']
col2=loan_df['Married']
col3=loan_df['Dependents']
col4=loan_df['Education']
col5=loan_df['Self_Employed']
col6=loan_df['Property_Area']
col7=loan_df['Loan_Status']
col=[col1,col2]
result=pd.crosstab(col6,col)
#result
result.plot(kind='bar')
plt.show()

# %%
#data=loan_df.corr(numeric_only=True)
#sns.heatmap(data,annot=True)

# %%
#loan_df.corr(numeric_only=True)

# %%
num
# Out:
# ['ApplicantIncome_imputed',
#  'CoapplicantIncome_imputed',
#  'LoanAmount_imputed',
#  'Loan_Amount_Term_imputed',
#  'Credit_History_imputed']

# %%
import matplotlib.pyplot as plt

# Calculate the total number of plots (rows * columns)
total_plots = 10 * 2

# Create a figure and axes for the subplots
fig, axes = plt.subplots(10, 2, figsize=(15, 30))  # 5 rows, 4 columns - Adjust the figsize as needed

# Your existing code with minor modifications
plot_counter = 0  # Initialize a counter for subplot positions

for i in num:
    for j in num:
        if i != j and plot_counter < total_plots:  # Check if plot_counter exceeds total_plots
            ax = axes[plot_counter // 2, plot_counter % 2]  # Get the current subplot
            ax.scatter(loan_df[i], loan_df[j])
            ax.set_title(f'Columns: {i} vs {j}')
            plot_counter += 1  # Increment the plot counter

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### COrrelation

# %%
num
# Out:
# ['ApplicantIncome_imputed',
#  'CoapplicantIncome_imputed',
#  'LoanAmount_imputed',
#  'Loan_Amount_Term_imputed',
#  'Credit_History_imputed']

# %%
list1=['ApplicantIncome_imputed',
       'CoapplicantIncome_imputed',
       'LoanAmount_imputed',
       'Loan_Amount_Term_imputed',
       'Credit_History_imputed']

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan_ID                    614 non-null    object
#  1   Gender                     614 non-null    object
#  2   Married                    614 non-null    object
#  3   Dependents                 614 non-null    object
#  4   Education                  614 non-null    object
#  5   Self_Employed              614 non-null    object
#  6   Property_Area              614 non-null    object
#  7   Loan_Status                614 non-null    object
#  8   ApplicantIncome_imputed    614 non-null    float64
#  9   CoapplicantIncome_imputed  614 non-null    float64
#  10  LoanAmount_imputed         614 non-null    float64
#  11  Loan_Amount_Term_imputed   614 non-null    float64
#  12  Credit_History_imputed     614 non-null    float64
# ...

# %%
loan_df.drop([0,1,2,3,4],axis=1,inplace=True)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Loan_ID                    614 non-null    object
#  1   Gender                     614 non-null    object
#  2   Married                    614 non-null    object
#  3   Dependents                 614 non-null    object
#  4   Education                  614 non-null    object
#  5   Self_Employed              614 non-null    object
#  6   Property_Area              614 non-null    object
#  7   Loan_Status                614 non-null    object
#  8   ApplicantIncome_imputed    614 non-null    float64
#  9   CoapplicantIncome_imputed  614 non-null    float64
#  10  LoanAmount_imputed         614 non-null    float64
#  11  Loan_Amount_Term_imputed   614 non-null    float64
#  12  Credit_History_imputed     614 non-null    float64
# ...

# %%
loan_df['LoanAmount_imputed'].unique()
# Out:
# array([128.,  66., 120., 141.,  95., 158., 168.,  70., 109., 200., 114.,
#        125., 100.,  76., 133., 115., 104., 116., 112., 151., 191., 122.,
#        110.,  35., 201.,  74., 106., 144., 184.,  80.,  47.,  75., 134.,
#         96.,  88.,  44.,  97., 135., 180.,  99., 165., 126., 136., 172.,
#         81., 187., 113., 176., 130., 111., 167.,  50., 210., 175., 131.,
#        188.,  25., 137., 160., 225., 216.,  94., 139., 152., 118., 185.,
#        154.,  85., 194.,  93., 182., 102.,  84., 129.,  30.,  98., 121.,
#         63.,  87., 101.,  67.,  73., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214.,  72.,  60., 138.,  42.,
#        140., 155., 123., 192., 150., 207.,  78.,  54.,  89., 143., 105.,
#        132.,  56., 159., 117.,  71., 173.,  46., 228., 156., 103.,  45.,
#         65.,  53.,  62., 218., 178., 148., 190., 149., 153., 162.,  86.,
#        186., 119., 107., 209., 208.,  40., 161., 196., 157., 145., 181.,
# ...

# %%
corr1=loan_df.corr(numeric_only=True)
corr1
# Out:
#                            ApplicantIncome_imputed  CoapplicantIncome_imputed  \
# ApplicantIncome_imputed                   1.000000                  -0.221149
# CoapplicantIncome_imputed                -0.221149                   1.000000
# LoanAmount_imputed                        0.309788                   0.218714
# Loan_Amount_Term_imputed                       NaN                        NaN
# Credit_History_imputed                         NaN                        NaN
#
#                            LoanAmount_imputed  Loan_Amount_Term_imputed  \
# ApplicantIncome_imputed              0.309788                       NaN
# CoapplicantIncome_imputed            0.218714                       NaN
# LoanAmount_imputed                   1.000000                       NaN
# Loan_Amount_Term_imputed                  NaN                       NaN
# Credit_History_imputed                    NaN                       NaN
#
#                            Credit_History_imputed
# ...

# %%
sns.heatmap(corr1)
# Out:
# <Axes: >

# %%
val1=loan_df[['ApplicantIncome_imputed','CoapplicantIncome_imputed','LoanAmount_imputed']]

# %%
corr_data=val1.corr(numeric_only=True)
corr_data
# Out:
#                            ApplicantIncome_imputed  CoapplicantIncome_imputed  \
# ApplicantIncome_imputed                   1.000000                  -0.221149
# CoapplicantIncome_imputed                -0.221149                   1.000000
# LoanAmount_imputed                        0.309788                   0.218714
#
#                            LoanAmount_imputed
# ApplicantIncome_imputed              0.309788
# CoapplicantIncome_imputed            0.218714
# LoanAmount_imputed                   1.000000

# %%
sns.heatmap(corr_data)
# Out:
# <Axes: >

# %% [markdown]
# ### EDA Part :- 6

# %% [markdown]
# - Label Encoder

# %%
cat
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
loan_df['Gender'].unique()
dict1={'Female':0,'Male':1}
loan_df['Gender']=loan_df['Gender'].map(dict1)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002       1      No          0      Graduate            No
# 1    LP001003       1     Yes          1      Graduate            No
# 2    LP001005       1     Yes          0      Graduate           Yes
# 3    LP001006       1     Yes          0  Not Graduate            No
# 4    LP001008       1      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978       0      No          0      Graduate            No
# 610  LP002979       1     Yes          4      Graduate            No
# 611  LP002983       1     Yes          1      Graduate            No
# 612  LP002984       1     Yes          2      Graduate            No
# 613  LP002990       0      No          0      Graduate           Yes
#
#     Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0           Urban           Y                  5849.00
# ...

# %%
loan_df['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x=loan_df['Married']=='Yes'
loan_df['Married']=np.where(x,1,0)
loan_df
# Out:
#       Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0    LP001002       1        0          0      Graduate            No
# 1    LP001003       1        1          1      Graduate            No
# 2    LP001005       1        1          0      Graduate           Yes
# 3    LP001006       1        1          0  Not Graduate            No
# 4    LP001008       1        0          0      Graduate            No
# ..        ...     ...      ...        ...           ...           ...
# 609  LP002978       0        0          0      Graduate            No
# 610  LP002979       1        1          4      Graduate            No
# 611  LP002983       1        1          1      Graduate            No
# 612  LP002984       1        1          2      Graduate            No
# 613  LP002990       0        0          0      Graduate           Yes
#
#     Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0           Urban           Y                  5849.00
# ...

# %%
loan_df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '4'], dtype=object)

# %%
from sklearn .preprocessing import LabelEncoder
le=LabelEncoder()
loan_df['Dependents']=le.fit_transform(loan_df['Dependents'])
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents     Education Self_Employed  \
# 0    LP001002       1        0           0      Graduate            No
# 1    LP001003       1        1           1      Graduate            No
# 2    LP001005       1        1           0      Graduate           Yes
# 3    LP001006       1        1           0  Not Graduate            No
# 4    LP001008       1        0           0      Graduate            No
# ..        ...     ...      ...         ...           ...           ...
# 609  LP002978       0        0           0      Graduate            No
# 610  LP002979       1        1           3      Graduate            No
# 611  LP002983       1        1           1      Graduate            No
# 612  LP002984       1        1           2      Graduate            No
# 613  LP002990       0        0           0      Graduate           Yes
#
#     Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0           Urban           Y                  5849.00
# ...

# %%
loan_df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
x=loan_df['Education']=='Graduate'
loan_df['Education']=np.where(x,1,0)
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education Self_Employed  \
# 0    LP001002       1        0           0          1            No
# 1    LP001003       1        1           1          1            No
# 2    LP001005       1        1           0          1           Yes
# 3    LP001006       1        1           0          0            No
# 4    LP001008       1        0           0          1            No
# ..        ...     ...      ...         ...        ...           ...
# 609  LP002978       0        0           0          1            No
# 610  LP002979       1        1           3          1            No
# 611  LP002983       1        1           1          1            No
# 612  LP002984       1        1           2          1            No
# 613  LP002990       0        0           0          1           Yes
#
#     Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0           Urban           Y                  5849.00
# ...

# %%
loan_df['Self_Employed'].dtypes
# Out:
# dtype('O')

# %%
loan_df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x=loan_df['Self_Employed']=='Graduate'
loan_df['Self_Employed']=np.where(x,1,0)
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              0
#
#     Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0           Urban           Y                  5849.00
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_df['Property_Area']=le.fit_transform(loan_df['Property_Area'])
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              0
#
#      Property_Area Loan_Status  ApplicantIncome_imputed  \
# 0                2           Y                  5849.00
# ...

# %%
x=loan_df['Loan_Status']=='Yes'
loan_df['Loan_Status']=np.where(x,1,0)
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              0
#
#      Property_Area  Loan_Status  ApplicantIncome_imputed  \
# 0                2            0                  5849.00
# ...

# %% [markdown]
#  ## EDA Part 7

# %% [markdown]
# - MiNMaxScalar
# - Z Score

# %% [markdown]
# **Normalization**

# %% [markdown]
# - ApplcantIncome_imputed

# %%
Min=round(loan_df['ApplicantIncome_imputed'].min(),2)
Max=round(loan_df['ApplicantIncome_imputed'].max(),2)
dr=Max-Min
nr=loan_df['ApplicantIncome_imputed']-Min
loan_df['ApplicantIncome_imputed_new']=nr/dr

# %%
loan_df[['ApplicantIncome_imputed','ApplicantIncome_imputed_new']]
# Out:
#      ApplicantIncome_imputed  ApplicantIncome_imputed_new
# 0                    5849.00                     0.746235
# 1                    4583.00                     0.580464
# 2                    3000.00                     0.373183
# 3                    2583.00                     0.318581
# 4                    6000.00                     0.766008
# ..                       ...                          ...
# 609                  2900.00                     0.360089
# 610                  4106.00                     0.518004
# 611                  3812.25                     0.479540
# 612                  7583.00                     0.973288
# 613                  4583.00                     0.580464
#
# [614 rows x 2 columns]

# %%
loan_df['ApplicantIncome_imputed_new'].max(),loan_df['ApplicantIncome_imputed_new'].min()
# Out:
# (1.0, 0.0)

# %%
loan_df['ApplicantIncome_imputed'].max(),loan_df['ApplicantIncome_imputed'].min()
# Out:
# (7787.0, 150.0)

# %%
max_id=loan_df['ApplicantIncome_imputed_new'].idxmax()
min_id=loan_df['ApplicantIncome_imputed_new'].idxmin()
max_id,min_id
# Out:
# (212, 216)

# %% [markdown]
# - CoApplicantIncome

# %%
Min=round(loan_df['CoapplicantIncome_imputed'].min(),2)
Max=round(loan_df['CoapplicantIncome_imputed'].max(),2)
dr=Max-Min
nr=loan_df['CoapplicantIncome_imputed']-Min
loan_df['CoapplicantIncome_imputed_new']=nr/dr

# %%
loan_df[['CoapplicantIncome_imputed','CoapplicantIncome_imputed_new']]
# Out:
#      CoapplicantIncome_imputed  CoapplicantIncome_imputed_new
# 0                          0.0                       0.000000
# 1                       1508.0                       0.284421
# 2                          0.0                       0.000000
# 3                       2358.0                       0.444738
# 4                          0.0                       0.000000
# ..                         ...                            ...
# 609                        0.0                       0.000000
# 610                        0.0                       0.000000
# 611                      240.0                       0.045266
# 612                        0.0                       0.000000
# 613                        0.0                       0.000000
#
# [614 rows x 2 columns]

# %%
loan_df['CoapplicantIncome_imputed_new'].max(),loan_df['CoapplicantIncome_imputed_new'].min()
# Out:
# (1.0, 0.0)

# %%
loan_df['CoapplicantIncome_imputed'].max(),loan_df['CoapplicantIncome_imputed'].min()
# Out:
# (5302.0, 0.0)

# %%
max_id=loan_df['CoapplicantIncome_imputed_new'].idxmax()
min_id=loan_df['CoapplicantIncome_imputed_new'].idxmin()
max_id,min_id
# Out:
# (503, 0)

# %% [markdown]
# - LoanAmount_Imputed

# %%
Min=round(loan_df['LoanAmount_imputed'].min(),2)
Max=round(loan_df['LoanAmount_imputed'].max(),2)
dr=Max-Min
nr=loan_df['LoanAmount_imputed']-Min
loan_df['LoanAmount_imputed_new']=nr/dr

# %%
loan_df[['LoanAmount_imputed','LoanAmount_imputed_new']]
# Out:
#      LoanAmount_imputed  LoanAmount_imputed_new
# 0                 128.0                0.507389
# 1                 128.0                0.507389
# 2                  66.0                0.201970
# 3                 120.0                0.467980
# 4                 141.0                0.571429
# ..                  ...                     ...
# 609                71.0                0.226601
# 610                40.0                0.073892
# 611               128.0                0.507389
# 612               187.0                0.798030
# 613               133.0                0.532020
#
# [614 rows x 2 columns]

# %%
loan_df['LoanAmount_imputed_new'].max(),loan_df['LoanAmount_imputed_new'].min()
# Out:
# (1.0, 0.0)

# %%
loan_df['LoanAmount_imputed'].max(),loan_df['LoanAmount_imputed'].min()
# Out:
# (228.0, 25.0)

# %%
max_id=loan_df['LoanAmount_imputed_new'].idxmax()
min_id=loan_df['LoanAmount_imputed_new'].idxmin()
max_id,min_id
# Out:
# (350, 94)

# %% [markdown]
# - LoanAmount_Term_Imputed

# %%
Min=round(loan_df['Loan_Amount_Term_imputed'].min(),2)
Max=round(loan_df['Loan_Amount_Term_imputed'].max(),2)
dr=Max-Min
nr=loan_df['Loan_Amount_Term_imputed']-Min
loan_df['Loan_Amount_Term_imputed_new']=nr/dr

# %%
loan_df[['Loan_Amount_Term_imputed','Loan_Amount_Term_imputed_new']]
# Out:
#      Loan_Amount_Term_imputed  Loan_Amount_Term_imputed_new
# 0                       360.0                           NaN
# 1                       360.0                           NaN
# 2                       360.0                           NaN
# 3                       360.0                           NaN
# 4                       360.0                           NaN
# ..                        ...                           ...
# 609                     360.0                           NaN
# 610                     360.0                           NaN
# 611                     360.0                           NaN
# 612                     360.0                           NaN
# 613                     360.0                           NaN
#
# [614 rows x 2 columns]

# %%
loan_df['Loan_Amount_Term_imputed_new'].max(),loan_df['Loan_Amount_Term_imputed_new'].min()
# Out:
# (nan, nan)

# %%
loan_df['Loan_Amount_Term_imputed'].max(),loan_df['Loan_Amount_Term_imputed'].min()
# Out:
# (360.0, 360.0)

# %%
max_id=loan_df['Loan_Amount_Term_imputed_new'].idxmax()
min_id=loan_df['Loan_Amount_Term_imputed_new'].idxmin()
max_id,min_id
# Out:
# (nan, nan)

# %%
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              0
#
#      Property_Area  Loan_Status  ApplicantIncome_imputed  \
# 0                2            0                  5849.00
# ...

# %% [markdown]
# ## Drop the extra new Column

# %%
loan_df.drop(columns=['ApplicantIncome_imputed_new',
                      'CoapplicantIncome_imputed_new',
                      'LoanAmount_imputed_new',
                      'Loan_Amount_Term_imputed_new'],axis=1,inplace=True)

# %% [markdown]
# ## standardization

# %%
num
# Out:
# ['ApplicantIncome_imputed',
#  'CoapplicantIncome_imputed',
#  'LoanAmount_imputed',
#  'Loan_Amount_Term_imputed',
#  'Credit_History_imputed']

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
loan_df["ApplicantIncome_imputed_ss"]=mms.fit_transform(loan_df[['ApplicantIncome_imputed']])
print(loan_df['ApplicantIncome_imputed_ss'].min())
print(loan_df['ApplicantIncome_imputed_ss'].max())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
loan_df["CoapplicantIncome_imputed_ss"]=mms.fit_transform(loan_df[['CoapplicantIncome_imputed']])
print(loan_df['CoapplicantIncome_imputed_ss'].min())
print(loan_df['CoapplicantIncome_imputed_ss'].max())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
loan_df["LoanAmount_imputed_ss"]=mms.fit_transform(loan_df[['LoanAmount_imputed']])
print(loan_df['LoanAmount_imputed_ss'].min())
print(loan_df['LoanAmount_imputed_ss'].max())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
loan_df["Loan_Amount_Term_imputed_ss"]=mms.fit_transform(loan_df[['Loan_Amount_Term_imputed']])
print(loan_df['Loan_Amount_Term_imputed_ss'].min())
print(loan_df['Loan_Amount_Term_imputed_ss'].max())
# Out:
# 0.0
# 0.0

# %%
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              0
#
#      Property_Area  Loan_Status  ApplicantIncome_imputed  \
# 0                2            0                  5849.00
# ...

# %%
loan_df.drop(columns=['ApplicantIncome_imputed_ss',
                      'CoapplicantIncome_imputed_ss',
                      'LoanAmount_imputed_ss',
                      'Loan_Amount_Term_imputed_ss'],axis=1,inplace=True)

# %%
loan_df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              0
#
#      Property_Area  Loan_Status  ApplicantIncome_imputed  \
# 0                2            0                  5849.00
# ...
